# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import gc
import os 
import fpfs
import fitsio
import galsim
import logging
import matplotlib.pylab as plt
from astropy.visualization import simple_norm
from mpl_toolkits.axes_grid1 import ImageGrid

import matplotlib as mpl
mpl.rcParams['axes.linewidth'] = 2.0 #set the value globally

# %%
a=fpfs.simutil.make_cosmo_sim(outDir,'g1-0000',Id0=0,ny=256,nx=256,do_write=False,return_array=True)
a=a[64:-64,64:-64]
plt.close()
outDir='galaxy_test_cosmo250_psf60'
plt.imshow(a,aspect='equal',cmap='RdYlBu_r',origin='lower',interpolation='None',\
             norm=simple_norm(a,'asinh',asinh_a=0.1,min_cut=-0.01,max_cut=0.2))
gc.collect()
# Out:
# 0

# %%
a=fpfs.simutil.make_cosmo_sim(outDir,'g1-0000',Id0=1,ny=256,nx=256,do_write=False,return_array=True)
a=a[64:-64,64:-64]
plt.close()
outDir='galaxy_test_cosmo250_psf60'
plt.imshow(a,aspect='equal',cmap='RdYlBu_r',origin='lower',interpolation='None',\
             norm=simple_norm(a,'asinh',asinh_a=0.1,min_cut=-0.01,max_cut=0.2))
gc.collect()
# Out:
# 0

# %%
a=fpfs.simutil.make_cosmo_sim(outDir,'g1-0000',Id0=2,ny=256,nx=256,do_write=False,return_array=True)
a=a[64:-64,64:-64]
plt.close()
outDir='galaxy_test_cosmo250_psf60'
plt.imshow(a,aspect='equal',cmap='RdYlBu_r',origin='lower',interpolation='None',\
             norm=simple_norm(a,'asinh',asinh_a=0.1,min_cut=-0.01,max_cut=0.2))
gc.collect()
# Out:
# 0

# %%
rcut=16
scale=0.168
ngrid=64
psf     =   galsim.Moffat(beta=2.5,fwhm=0.6,).shear(g1=0.02, g2=-0.02,)
psf     =   psf.shift(
    dx  =   0.5*scale,
    dy  =   0.5*scale,
)

psfData =   psf.drawImage(nx=ngrid,ny=ngrid,scale=scale).array

results=[]

fpTask  =   fpfs.image.measure_source(psfData,noiFit=0.,beta=0.5)
for _ in range(4):
    gal=fpfs.simutil.make_cosmo_sim(outDir,'g1-0000',Id0=2,ny=256,nx=256,do_write=False,return_array=True)
    a=a[ngrid*2:-ngrid*2,ngrid*2:-ngrid*2]
    beg =   ngrid//2-rcut
    end =   beg+2*rcut
    gal =   gal[beg:end,beg:end]
    modes=  fpTask.measure(gal)
    results.append(modes)
    del gal,modes,beg,end,ngrid
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [18], in <cell line: 14>()
#      10 psfData =   psf.drawImage(nx=ngrid,ny=ngrid,scale=scale)
#      12 results=[]
# ---> 14 fpTask  =   fpfs.image.measure_source(psfData,noiFit=0.,beta=0.5)
#      15 for _ in range(4):
#      16     gal=fpfs.simutil.make_cosmo_sim(outDir,'g1-0000',Id0=2,ny=256,nx=256,do_write=False,return_array=True)
#
# File /lustre/work/xiangchong.li/superonionIDark/code/FPFS/fpfs/image.py:116, in measure_source.__init__(self, psfData, beta, nnord, noiModel, noiFit, debug, pix_scale)
#     114 if beta>=1. or beta<=0.:
#     115     raise ValueError('Input beta should be in range (0,1)')
# --> 116 self.ngrid  =   psfData.shape[0]
#     117 self.pix_scale= pix_scale # this is only used to normalize basis functions
#     118 self._dk    =   2.*np.pi/self.ngrid # assuming pixel scale is 1
#
# AttributeError: 'Image' object has no attribute 'shape'

# %%
mms =   rfn.stack_arrays(results,usemask=False)
ells=   fpfs.catalog.fpfsM2E(mms,const=2000,noirev=noirev)
del mms,results
resp=np.average(ells['fpfs_R1E'])
shear=np.average(ells['fpfs_e1'])/resp
shear_err=np.std(ells['fpfs_e1'])/np.abs(resp)/np.sqrt(num_gals)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 3>()
#       8 end =   beg+2*rcut
#       9 gal =   gal[beg:end,beg:end]
# ---> 10 modes=  fpTask.measure(gal)
#      11 results.append(modes)
#      12 del gal,modes,beg,end,ngrid
#
# NameError: name 'fpTask' is not defined
