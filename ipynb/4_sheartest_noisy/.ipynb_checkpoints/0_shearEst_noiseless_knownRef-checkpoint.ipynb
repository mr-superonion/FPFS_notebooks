# %%
# %pylab inline

import gc
import pdet
import fpfs
import fitsio
import pltutil
import numpy as np
import numpy.lib.recfunctions as rfn
import matplotlib.pylab as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Do not have lsst pipeline!

# %%
# merge data from n fields
out1=[]
out2=[]
for _i in range(125):
    _a1=fitsio.read('../../sim/src_basicCenter-var0em0/psf60/fpfs-cut16-%04d-g1-0000.fits' %_i)
    _a2=fitsio.read('../../sim/src_basicCenter-var0em0/psf60/fpfs-cut16-%04d-g1-2222.fits' %_i)
    out1.append(_a1)
    out2.append(_a2)
out1 =   rfn.stack_arrays(out1,usemask=False)
out2 =   rfn.stack_arrays(out2,usemask=False)
    
gc.collect()
ell1=fpfs.fpfsBase.fpfsM2E(out1,const=100)
ell2=fpfs.fpfsBase.fpfsM2E(out2,const=100)
out1=pdet.make_detection_array(out1,ell1)
out2=pdet.make_detection_array(out2,ell2)
gc.collect()
# Out:
# 0

# %%
dcc=0.02
x=[]
y1=[]
y2=[]
ttlist=[(2,1),(1,1)]#,(1,2),(3,2)]
for i in range(0,10):
    cut=0.2*i
    cutList=np.array([cut]*(len(ttlist)))
    msk1=np.ones(len(out1),dtype=bool)
    msk2=np.ones(len(out2),dtype=bool)
    for j in range(len(ttlist)):
        tt=ttlist[j]
        c=cutList[j]
        pn='f%d%d' %tt
        msk1 &= (out1['pdet_%s' %pn]>c)
        msk2 &= (out2['pdet_%s' %pn]>c)
    outM1=out1[msk1]
    ellM1=ell1[msk1]
    outM2=out2[msk2]
    ellM2=ell2[msk2]
    cor1 = pdet.get_detbias(outM1,cut,dcc,inds=ttlist,dcutz=False)[0]
    cor2 = pdet.get_detbias(outM2,cut,dcc,inds=ttlist,dcutz=False)[0]
    de   = np.sum(ellM2['fpfs_e1'])-np.sum(ellM1['fpfs_e1'])
    rave = (np.sum(ellM2['fpfs_RE'])+np.sum(ellM1['fpfs_RE']))/2.
    raveR= (np.sum(ellM2['fpfs_RE'])+np.sum(ellM1['fpfs_RE'])+cor1+cor2)/2.
    x.append(cut)
    y1.append(de/rave/0.04-1)
    y2.append(de/raveR/0.04-1)
    del msk1,msk2
gc.collect()
# Out:
# 23

# %%
plt.close()
fig,axes=pltutil.make_figure_axes(1,1)
ax=axes[0]
ax.plot(np.array(x),np.array(y1),label='w/o correction',color=pltutil.colors[0])
ax.plot(np.array(x),np.array(y2),label='with correction',color=pltutil.colors[1])
ax.set_xlabel('peak value cut')
ax.set_ylabel('multiplicative bias')
#ax.set_ylim(-0.05,0.01)
ax.grid()
ax.legend()

# %%
plt.close()
fig,axes=pltutil.make_figure_axes(1,1)
ax=axes[0]
ax.hist(out1['pdet_f21'],range=(0,3),bins=300,color=pltutil.colors[0])
ax.set_yscale('log')
ax.set_xlabel('peak value')
ax.set_ylabel('number')
ax.grid()
