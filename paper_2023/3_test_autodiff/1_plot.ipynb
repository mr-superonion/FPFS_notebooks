# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import gc
import os
import glob
import fitsio
from fpfs import pltutil
import matplotlib.pylab as plt
import matplotlib as mpl
mpl.rcParams['axes.linewidth'] = 2.0 #set the value globally

# %%
10 ** ((27- 25.) / 2.5)
# Out:
# 6.309573444801933

# %%
plt.close()
fig,axes=pltutil.make_figure_axes(ny=2,nx=1,square=False)
ax=axes[0]
xlabel=r'$m_{\rm F}$ upper limit';
ax.set_ylabel('$m$ $[10^{-2}]$',fontsize=18)
ax.set_yscale('symlog',linthresh=1.)
ax.set_yticks([-5,-1,-0.5,0.,0.5,1,5])
ax.set_yticklabels(['-5','-1','-0.5','0.','0.5','1','5'])
ax.set_xlim(22.7,25.6)
ax.axvline(25.,color='black',ls='-.')
ax.set_ylim(-0.6,0.6)
ax.invert_xaxis()
ax.tick_params(width=2,size=4)
ax.set_xticklabels([])
ax.grid()
ax.spines['bottom'].set_visible(False)
ax.axhspan(-0.3,0.3,0,100,color='gray',alpha=0.3)

ax2=axes[1]
ax2.set_ylabel('$c$ $[10^{-4}]$',fontsize=18)
ax2.set_xlim(22.7,25.6)
ax2.axvline(25.,color='black',ls='-.')
ax2.set_ylim(-0.2,0.5)
ax2.tick_params(width=2,size=4)
ax2.set_xlabel(xlabel,fontsize=18)
ax2.grid()
ax2.invert_xaxis()
plt.tight_layout(h_pad=-0.2)

outs=fitsio.read('output_mag_cut.fits')
x=np.array([25.3,24.7, 24.1,23.5, 22.9])
y1 = outs[:,0]
yerr = outs[:,1]
z1 = outs[:,2]
zerr = outs[:,3]
ax.errorbar(np.array(x)+0.02,np.array(y1)*1e2,np.array(yerr)*1e2,color=pltutil.colors[1], ls='-', linewidth =2.5)
ax2.errorbar(np.array(x)+0.02,np.array(z1)*1e4,np.array(zerr)*1e4,color=pltutil.colors[1], ls='-', linewidth =2.5)

outs=fitsio.read('output_mag_cut_2.fits')
x=np.array([25.3,24.7, 24.1,23.5, 22.9])
y1 = outs[:,0]
yerr = outs[:,1]
z1 = outs[:,2]
zerr = outs[:,3]
ax.errorbar(np.array(x)-0.02,np.array(y1)*1e2,np.array(yerr)*1e2,color=pltutil.colors[2], ls='--', linewidth =2.5)
ax2.errorbar(np.array(x)-0.02,np.array(z1)*1e4,np.array(zerr)*1e4,color=pltutil.colors[2], ls='--', linewidth =2.5)

plt.tight_layout(h_pad=-0.2)
fig.savefig('blend_magcut_final.pdf')

# %%
# make plot
plt.close()
fig,axes=pltutil.make_figure_axes(ny=2,nx=1,square=False)
ax=axes[0]
xlabel='$R_{2}$ lower limit';
ax.set_ylabel('$m$ $[10^{-2}]$',fontsize=18)
ax.set_ylim(-0.65,0.05)

ax.set_xlim(-0.02,0.22)
ax.axvline(0.05,color='black',ls='-.')
ax.tick_params(width=2,size=4)
ax.set_xticklabels([])
ax.grid()
ax.spines['bottom'].set_visible(False)
ax.axhspan(-0.3,0.3,0,100,color='gray',alpha=0.3)

ax2=axes[1]
ax2.set_ylabel('$c$ $[10^{-4}]$',fontsize=18)
ax2.set_ylim(-0.,0.45)
ax2.set_xlim(-0.02,0.22)
ax2.axvline(0.05,color='black',ls='-.')

ax2.tick_params(width=2,size=4)
ax2.set_xlabel(xlabel,fontsize=18)
ax2.grid()

outs=fitsio.read('output_r2_cut.fits')
x=np.array([ 0.,0.05, 0.1, 0.15, 0.20])
y1 = outs[:,0]
yerr = outs[:,1]
z1 = outs[:,2]
zerr = outs[:,3]
ax.errorbar(np.array(x)+0.003,np.array(y1)*1e2,np.array(yerr)*1e2,color=pltutil.colors[1], ls='-', linewidth =2.5)
ax2.errorbar(np.array(x)+0.003,np.array(z1)*1e4,np.array(zerr)*1e4,color=pltutil.colors[1], ls='-', linewidth =2.5)

outs=fitsio.read('output_r2_cut_2.fits')
x=np.array([ 0.,0.05, 0.1, 0.15, 0.20])
y1 = outs[:,0]
yerr = outs[:,1]
z1 = outs[:,2]
zerr = outs[:,3]
ax.errorbar(np.array(x)-0.003,np.array(y1)*1e2,np.array(yerr)*1e2,color=pltutil.colors[2], ls='--', linewidth =2.5)
ax2.errorbar(np.array(x)-0.003,np.array(z1)*1e4,np.array(zerr)*1e4,color=pltutil.colors[2], ls='--', linewidth =2.5)


plt.tight_layout(h_pad=-0.2)
fig.savefig('blend_r2cut_final.pdf')
